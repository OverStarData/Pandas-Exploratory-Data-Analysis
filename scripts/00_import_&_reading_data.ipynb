# %% [markdown]
# # 00- Import & Reading Data

# %%
# import libs

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read data and set rows & columns options
df = pd.read_csv('/Users/deadman/Documents/Pandas-Exploratory Data Analysis/data/coaster_db.csv')

plt.style.use('ggplot')

pd.set_option("display.max_rows",200)
pd.set_option("display.max_columns",200)
# Out:
#          coaster_name          Length             Speed       Location  \
# 0  Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)   Coney Island
# 1   Flip Flap Railway             NaN               NaN  Sea Lion Park
#
#     Status   Opening date  Type            Manufacturer Height restriction  \
# 0  Removed  June 16, 1884  Wood  LaMarcus Adna Thompson                NaN
# 1  Removed           1895  Wood            Lina Beecher                NaN
#
#          Model        Height  Inversions Lift/launch system Cost  \
# 0  Lift Packed  50 ft (15 m)         NaN            gravity  NaN
# 1          NaN           NaN         1.0                NaN  NaN
#
#                                               Trains  \
# 0                                                NaN
# 1  a single car. Riders are arranged 1 across in ...
#
#                 Park section Duration              Capacity G-force  \
# 0  Coney Island Cyclone Site     1:00  1600 riders per hour     2.9
# ...

# %%
df.head(2)
# Out:
#          coaster_name          Length             Speed       Location  \
# 0  Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)   Coney Island
# 1   Flip Flap Railway             NaN               NaN  Sea Lion Park
#
#     Status   Opening date  Type            Manufacturer Height restriction  \
# 0  Removed  June 16, 1884  Wood  LaMarcus Adna Thompson                NaN
# 1  Removed           1895  Wood            Lina Beecher                NaN
#
#          Model        Height  Inversions Lift/launch system Cost  \
# 0  Lift Packed  50 ft (15 m)         NaN            gravity  NaN
# 1          NaN           NaN         1.0                NaN  NaN
#
#                                               Trains  \
# 0                                                NaN
# 1  a single car. Riders are arranged 1 across in ...
#
#                 Park section Duration              Capacity G-force  \
# 0  Coney Island Cyclone Site     1:00  1600 riders per hour     2.9
# ...

# %%
# explore df dimentions

df.shape
# Out:
# (1087, 56)

# %%
# show df columns 

df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
# show columns data dtypes

df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
# show  single column data dtypes

df['Status'].dtype
# Out:
# dtype('O')

# %%
# show information about columns & it data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
# count columns values 

df.count()
# Out:
# coaster_name                     1087
# Length                            953
# Speed                             937
# Location                         1087
# Status                            874
# Opening date                      837
# Type                             1087
# Manufacturer                     1028
# Height restriction                831
# Model                             744
# Height                            965
# Inversions                        932
# Lift/launch system                795
# Cost                              382
# Trains                            718
# Park section                      487
# Duration                          765
# Capacity                          575
# G-force                           362
# Designer                          578
# Max vertical angle                357
# Drop                              494
# Soft opening date                  96
# Fast Lane available                69
# Replaced                          173
# ...

# %%
# explore measure data and aggregate 

df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
# count of unique values on column Status

df['Status'].nunique()
# Out:
# 15

# %%
# show unique values on column Status

df['Status'].unique()
# Out:
# array(['Removed', 'Closed', 'Operating', nan, 'Not Currently Operating',
#        'In Production', 'Discontinued',
#        'closed for maintenance as of july 30 no reopening date known',
#        'Closed in 2021', 'SBNO December 2019', 'Under construction',
#        'Temporarily Closed', 'SBNO (Standing But Not Operating)',
#        'Temporarily closed',
#        'Chapter 7 bankruptcy; rides dismantled and sold; property sold',
#        'Under Maintenance'], dtype=object)
